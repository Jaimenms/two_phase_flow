# %% [markdown]
# # Generation of Finite Difference Formulas on Arbitrarily Spaced Grids
# ## Fornberg (1988)

# %%
import os, sys
dir2 = os.path.abspath('')
dir1 = os.path.dirname(dir2)
if not dir1 in sys.path:
    sys.path.append(dir1)

from methods.fdm.taylor_tables.tools import print_taylor_table

# %% [markdown]
# ## First order derivative

# %%
M=1

# %%
N=1
kind="heterogeneous"
print("**{}** with order={}".format(kind, N))
print_taylor_table(M, N, kind=kind)
# Out:
# **heterogeneous** with order=1
# #
# #df/dx(x[0])
# out[0][0] = lambda x : -1/(-x[0] + x[1])
# out[0][1] = lambda x : 1/(-x[0] + x[1])
# #
# #df/dx(x[1])
# out[1][0] = lambda x : -1/(-x[0] + x[1])
# out[1][1] = lambda x : 1/(-x[0] + x[1])

# %%
N=2
kind="heterogeneous"
print("**{}** with order={}".format(kind, N))
print_taylor_table(M, N, kind=kind)
# Out:
# **heterogeneous** with order=2
# #
# #df/dx(x[0])
# out[0][0] = lambda x : (-1 - (-x[0] + x[2])/(-x[0] + x[1]))/(-x[0] + x[2])
# out[0][1] = lambda x : (-x[0] + x[2])/((-x[0] + x[1])*(-x[1] + x[2]))
# out[0][2] = lambda x : -(-x[0] + x[1])/((-x[0] + x[2])*(-x[1] + x[2]))
# #
# #df/dx(x[1])
# out[1][0] = lambda x : -(-x[1] + x[2])/((-x[0] + x[1])*(-x[0] + x[2]))
# out[1][1] = lambda x : (-1 + (-x[1] + x[2])/(-x[0] + x[1]))/(-x[1] + x[2])
# out[1][2] = lambda x : (-x[0] + x[1])/((-x[0] + x[2])*(-x[1] + x[2]))
# #
# #df/dx(x[2])
# out[2][0] = lambda x : -(x[1] - x[2])/((-x[0] + x[1])*(-x[0] + x[2]))
# out[2][1] = lambda x : -(-x[0] + x[2])/((-x[0] + x[1])*(-x[1] + x[2]))
# out[2][2] = lambda x : (-x[0] + x[1])*((-x[0] + x[2])/(-x[0] + x[1]) - (x[1] - x[2])/(-x[0] + x[1]))/((-x[0] + x[2])*(-x[1] + x[2]))

# %%
N=4
kind="heterogeneous"
print("**{}** with order={}".format(kind, N))
print_taylor_table(M, N, kind=kind)
# Out:
# **heterogeneous** with order=4
# #
# #df/dx(x[0])
# out[0][0] = lambda x : (-1 + (-x[0] + x[4])*((-1 - (-x[0] + x[2])/(-x[0] + x[1]))*(-x[0] + x[3])/(-x[0] + x[2]) - 1)/(-x[0] + x[3]))/(-x[0] + x[4])
# out[0][1] = lambda x : (-x[0] + x[2])*(-x[0] + x[3])*(-x[0] + x[4])/((-x[0] + x[1])*(-x[1] + x[2])*(-x[1] + x[3])*(-x[1] + x[4]))
# out[0][2] = lambda x : -(-x[0] + x[1])*(-x[0] + x[3])*(-x[0] + x[4])/((-x[0] + x[2])*(-x[1] + x[2])*(-x[2] + x[3])*(-x[2] + x[4]))
# out[0][3] = lambda x : (-x[0] + x[1])*(-x[0] + x[2])*(-x[0] + x[4])/((-x[0] + x[3])*(-x[1] + x[3])*(-x[2] + x[3])*(-x[3] + x[4]))
# out[0][4] = lambda x : -(-x[0] + x[1])*(-x[0] + x[2])*(-x[0] + x[3])/((-x[0] + x[4])*(-x[1] + x[4])*(-x[2] + x[4])*(-x[3] + x[4]))
# #
# #df/dx(x[1])
# out[1][0] = lambda x : -(-x[1] + x[2])*(-x[1] + x[3])*(-x[1] + x[4])/((-x[0] + x[1])*(-x[0] + x[2])*(-x[0] + x[3])*(-x[0] + x[4]))
# ...

# %%
N=6
kind="heterogeneous"
print("**{}** with order={}".format(kind, N))
print_taylor_table(M, N, kind=kind)
# Out:
# **heterogeneous** with order=6
# #
# #df/dx(x[0])
# out[0][0] = lambda x : (-1 + (-x[0] + x[6])*((-1 + (-x[0] + x[4])*((-1 - (-x[0] + x[2])/(-x[0] + x[1]))*(-x[0] + x[3])/(-x[0] + x[2]) - 1)/(-x[0] + x[3]))*(-x[0] + x[5])/(-x[0] + x[4]) - 1)/(-x[0] + x[5]))/(-x[0] + x[6])
# out[0][1] = lambda x : (-x[0] + x[2])*(-x[0] + x[3])*(-x[0] + x[4])*(-x[0] + x[5])*(-x[0] + x[6])/((-x[0] + x[1])*(-x[1] + x[2])*(-x[1] + x[3])*(-x[1] + x[4])*(-x[1] + x[5])*(-x[1] + x[6]))
# out[0][2] = lambda x : -(-x[0] + x[1])*(-x[0] + x[3])*(-x[0] + x[4])*(-x[0] + x[5])*(-x[0] + x[6])/((-x[0] + x[2])*(-x[1] + x[2])*(-x[2] + x[3])*(-x[2] + x[4])*(-x[2] + x[5])*(-x[2] + x[6]))
# out[0][3] = lambda x : (-x[0] + x[1])*(-x[0] + x[2])*(-x[0] + x[4])*(-x[0] + x[5])*(-x[0] + x[6])/((-x[0] + x[3])*(-x[1] + x[3])*(-x[2] + x[3])*(-x[3] + x[4])*(-x[3] + x[5])*(-x[3] + x[6]))
# ...

# %%
N=8
kind="heterogeneous"
print("**{}** with order={}".format(kind, N))
print_taylor_table(M, N, kind=kind)
# Out:
# **heterogeneous** with order=8
# #
# #df/dx(x[0])
# out[0][0] = lambda x : (-1 + (-x[0] + x[8])*((-1 + (-x[0] + x[6])*((-1 + (-x[0] + x[4])*((-1 - (-x[0] + x[2])/(-x[0] + x[1]))*(-x[0] + x[3])/(-x[0] + x[2]) - 1)/(-x[0] + x[3]))*(-x[0] + x[5])/(-x[0] + x[4]) - 1)/(-x[0] + x[5]))*(-x[0] + x[7])/(-x[0] + x[6]) - 1)/(-x[0] + x[7]))/(-x[0] + x[8])
# out[0][1] = lambda x : (-x[0] + x[2])*(-x[0] + x[3])*(-x[0] + x[4])*(-x[0] + x[5])*(-x[0] + x[6])*(-x[0] + x[7])*(-x[0] + x[8])/((-x[0] + x[1])*(-x[1] + x[2])*(-x[1] + x[3])*(-x[1] + x[4])*(-x[1] + x[5])*(-x[1] + x[6])*(-x[1] + x[7])*(-x[1] + x[8]))
# out[0][2] = lambda x : -(-x[0] + x[1])*(-x[0] + x[3])*(-x[0] + x[4])*(-x[0] + x[5])*(-x[0] + x[6])*(-x[0] + x[7])*(-x[0] + x[8])/((-x[0] + x[2])*(-x[1] + x[2])*(-x[2] + x[3])*(-x[2] + x[4])*(-x[2] + x[5])*(-x[2] + x[6])*(-x[2] + x[7])*(-x[2] + x[8]))
# ...

# %% [markdown]
# ## Second order derivative

# %%
M=2

# %%
N=2
kind="heterogeneous"
print("**{}** with order={}".format(kind, N))
print_taylor_table(M, N, kind=kind)
# Out:
# **heterogeneous** with order=2
# #
# #df/dx(x[0])
# out[0][0] = lambda x : 2/((-x[0] + x[1])*(-x[0] + x[2]))
# out[0][1] = lambda x : -2/((-x[0] + x[1])*(-x[1] + x[2]))
# out[0][2] = lambda x : 2/((-x[0] + x[2])*(-x[1] + x[2]))
# #
# #df/dx(x[1])
# out[1][0] = lambda x : 2/((-x[0] + x[1])*(-x[0] + x[2]))
# out[1][1] = lambda x : -2/((-x[0] + x[1])*(-x[1] + x[2]))
# out[1][2] = lambda x : 2/((-x[0] + x[2])*(-x[1] + x[2]))
# #
# #df/dx(x[2])
# out[2][0] = lambda x : 2/((-x[0] + x[1])*(-x[0] + x[2]))
# out[2][1] = lambda x : -2/((-x[0] + x[1])*(-x[1] + x[2]))
# out[2][2] = lambda x : 2/((-x[0] + x[2])*(-x[1] + x[2]))

# %%
N=4
kind="heterogeneous"
print("**{}** with order={}".format(kind, N))
print_taylor_table(M, N, kind=kind)
# Out:
# **heterogeneous** with order=4
# #
# #df/dx(x[0])
# out[0][0] = lambda x : ((-x[0] + x[4])*(-2*(-1 - (-x[0] + x[2])/(-x[0] + x[1]))/(-x[0] + x[2]) + 2*(-x[0] + x[3])/((-x[0] + x[1])*(-x[0] + x[2])))/(-x[0] + x[3]) - 2*((-1 - (-x[0] + x[2])/(-x[0] + x[1]))*(-x[0] + x[3])/(-x[0] + x[2]) - 1)/(-x[0] + x[3]))/(-x[0] + x[4])
# out[0][1] = lambda x : ((-x[0] + x[4])*(-2*(-x[0] + x[2])/((-x[0] + x[1])*(-x[1] + x[2])) - 2*(-x[0] + x[3])/((-x[0] + x[1])*(-x[1] + x[2])))/(-x[1] + x[3]) - 2*(-x[0] + x[2])*(-x[0] + x[3])/((-x[0] + x[1])*(-x[1] + x[2])*(-x[1] + x[3])))/(-x[1] + x[4])
# out[0][2] = lambda x : (2*(-x[0] + x[1])*(-x[0] + x[3])/((-x[0] + x[2])*(-x[1] + x[2])*(-x[2] + x[3])) + (-x[0] + x[4])*(2*(-x[0] + x[1])/((-x[0] + x[2])*(-x[1] + x[2])) + 2*(-x[0] + x[3])/((-x[0] + x[2])*(-x[1] + x[2])))/(-x[2] + x[3]))/(-x[2] + x[4])
# ...

# %%
N=6
kind="heterogeneous"
print("**{}** with order={}".format(kind, N))
print_taylor_table(M, N, kind=kind)
# Out:
# **heterogeneous** with order=6
# #
# #df/dx(x[0])
# out[0][0] = lambda x : ((-x[0] + x[6])*(-2*(-1 + (-x[0] + x[4])*((-1 - (-x[0] + x[2])/(-x[0] + x[1]))*(-x[0] + x[3])/(-x[0] + x[2]) - 1)/(-x[0] + x[3]))/(-x[0] + x[4]) + (-x[0] + x[5])*((-x[0] + x[4])*(-2*(-1 - (-x[0] + x[2])/(-x[0] + x[1]))/(-x[0] + x[2]) + 2*(-x[0] + x[3])/((-x[0] + x[1])*(-x[0] + x[2])))/(-x[0] + x[3]) - 2*((-1 - (-x[0] + x[2])/(-x[0] + x[1]))*(-x[0] + x[3])/(-x[0] + x[2]) - 1)/(-x[0] + x[3]))/(-x[0] + x[4]))/(-x[0] + x[5]) - 2*((-1 + (-x[0] + x[4])*((-1 - (-x[0] + x[2])/(-x[0] + x[1]))*(-x[0] + x[3])/(-x[0] + x[2]) - 1)/(-x[0] + x[3]))*(-x[0] + x[5])/(-x[0] + x[4]) - 1)/(-x[0] + x[5]))/(-x[0] + x[6])
# ...

# %%
N=8
kind="heterogeneous"
print("**{}** with order={}".format(kind, N))
print_taylor_table(M, N, kind=kind)
# Out:
# **heterogeneous** with order=8
# #
# #df/dx(x[0])
# ...
